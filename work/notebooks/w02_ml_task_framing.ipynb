# %% [markdown]
# <a href="https://colab.research.google.com/github/hafsajavedkkk/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hafsajavedkkk/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Task type: Classification. My goal is to classify each item into the appropriate category using the available features. Classification fits because the desired output is a defined category rather than a continuous numerical value.

# %%
task_type = "classification"
print("ML task type:", task_type)
# Out:
# ML task type: classification

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Target: The target is the category assigned to each item. The label comes from the existing labeled examples in the dataset, which the model can learn from to classify new examples.

# %%
target = "category"
print("Target column:", target)
# Out:
# Target column: category

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Success metric: F1-score. I will use F1-score because it balances precision and recall. An F1-score of 0.80 or higher would be a good initial result.

# %%
success_metric = "F1-score"
good_threshold = 0.80

print("Success metric:", success_metric)
print("Good result:", good_threshold)
# Out:
# Success metric: F1-score
# Good result: 0.8

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# Unit of analysis: One row represents one item/example that the model will classify. The dataframe contains the features used for prediction, with a target column representing the category to predict.

# %%
import pandas as pd

df = pd.DataFrame({
    "text_length": [120, 250, 80, 310, 175],
    "engagement": [15, 42, 8, 55, 27],
    "category": ["A", "B", "A", "B", "A"]
})

print("One row = one item to classify")
display(df)

print("\nTarget column:")
display(df[["category"]])
# Out:
# One row = one item to classify
#    text_length  engagement category
# 0          120          15        A
# 1          250          42        B
# 2           80           8        A
# 3          310          55        B
# 4          175          27        A
# Target column:
#   category
# 0        A
# 1        B
# 2        A
# 3        B
# 4        A

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Why ML beats a fixed rule: The outcome depends on patterns across multiple features, so a simple if-statement would be too rigid. ML can learn these patterns from observed examples and provide predictions that support classification and prioritization decisions.

# %%
feature_count = 2

print("Features considered:", feature_count)
print("A fixed rule may miss interactions between multiple features.")
print("ML can learn these patterns from observed examples.")
# Out:
# Features considered: 2
# A fixed rule may miss interactions between multiple features.
# ML can learn these patterns from observed examples.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
