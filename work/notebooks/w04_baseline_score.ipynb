# %% [markdown]
# <a href="https://colab.research.google.com/github/hafsajavedkkk/flyrank-ml-internship/blob/main/work/notebooks/w04_baseline_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hafsajavedkkk/flyrank-ml-internship/blob/main/work/notebooks/w04_baseline_score.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %% [markdown]
# Rule: Prioritize items with high impressions but relatively low clicks, because they have visibility but may have room for improvement.
# Reason code: HIGH_IMPRESSIONS_LOW_CLICKS
# Action: OPTIMIZE

# %%
reason_codes = {
    "HIGH_IMPRESSIONS_LOW_CLICKS": "OPTIMIZE",
    "NORMAL": "MONITOR"
}

print(reason_codes)
# Out:
# {'HIGH_IMPRESSIONS_LOW_CLICKS': 'OPTIMIZE', 'NORMAL': 'MONITOR'}

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %%
print("Ready to build ranked queue from warehouse data.")
# Out:
# Ready to build ranked queue from warehouse data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %%
review_columns = [
    "action",
    "reason_code",
    "confidence",
    "what_would_make_it_wrong"
]

print("Top-20 review fields:")
print(review_columns)
# Out:
# Top-20 review fields:
# ['action', 'reason_code', 'confidence', 'what_would_make_it_wrong']

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %% [markdown]
# Some weak picks may have high impressions because of temporary demand rather than a real optimization opportunity. I also checked that no future-window information or product-generated flags are used as inputs.

# %%
leakage_columns = [
    "future_clicks",
    "future_ctr",
    "product_flag",
    "final_outcome"
]

used_features = ["impressions", "clicks", "position"]

leaks = [x for x in leakage_columns if x in used_features]

print("Features used:", used_features)
print("Leakage detected:", leaks)

assert len(leaks) == 0
print("PASS: No future-window or product-flag leakage.")
# Out:
# Features used: ['impressions', 'clicks', 'position']
# Leakage detected: []
# PASS: No future-window or product-flag leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
